# %% [markdown]
# # Data Consistency Checks

# %% [markdown]
# ## This script contains the following points:

# %% [markdown]
# ### 1. Import Libraries

# %% [markdown]
# ### 2. Import Data

# %% [markdown]
# ### 3. Data Consistency Checks

# %% [markdown]
# #### 3.1 Data Types

# %% [markdown]
# #### 3.2 Missing Data

# %% [markdown]
# #### 3.3 Duplicate Data

# %% [markdown]
# #### 3.4 Descriptive Statistics

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 2. Import Data

# %%
# Creating path string to data folder
path = r'C:\Users\bexlu\Desktop\Career Foundry\Data Immersion\Achievement 6\Project Folder'

# %%
# Importing csv file using os library
df = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'Hate Crimes.csv'), index_col = False)
# Out:
# C:\Users\bexlu\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (19) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# Print of first five rows of df
df.head()
# Out:
#    INCIDENT_ID  DATA_YEAR        ORI PUB_AGENCY_NAME PUB_AGENCY_UNIT  \
# 0         3015       1991  AR0040200          Rogers             NaN
# 1         3016       1991  AR0290100            Hope             NaN
# 2           43       1991  AR0350100      Pine Bluff             NaN
# 3           44       1991  AR0350100      Pine Bluff             NaN
# 4         3017       1991  AR0350100      Pine Bluff             NaN
#
#   AGENCY_TYPE_NAME STATE_ABBR STATE_NAME       DIVISION_NAME REGION_NAME  ...  \
# 0             City         AR   Arkansas  West South Central       South  ...
# 1             City         AR   Arkansas  West South Central       South  ...
# 2             City         AR   Arkansas  West South Central       South  ...
# 3             City         AR   Arkansas  West South Central       South  ...
# 4             City         AR   Arkansas  West South Central       South  ...
#
#                OFFENDER_RACE OFFENDER_ETHNICITY VICTIM_COUNT  \
# 0                      White                NaN            1
# 1  Black or African American                NaN            1
# 2  Black or African American                NaN            1
# 3  Black or African American                NaN            2
# 4  Black or African American                NaN            1
#
#                                         OFFENSE_NAME  \
# 0                                       Intimidation
# 1                                     Simple Assault
# 2                                 Aggravated Assault
# 3  Aggravated Assault;Destruction/Damage/Vandalis...
# 4                                 Aggravated Assault
#
#    TOTAL_INDIVIDUAL_VICTIMS                       LOCATION_NAME  \
# 0                       1.0  Highway/Road/Alley/Street/Sidewalk
# 1                       1.0  Highway/Road/Alley/Street/Sidewalk
# 2                       1.0                      Residence/Home
# 3                       1.0  Highway/Road/Alley/Street/Sidewalk
# 4                       1.0                 Service/Gas Station
#
#                         BIAS_DESC  VICTIM_TYPES MULTIPLE_OFFENSE MULTIPLE_BIAS
# 0  Anti-Black or African American    Individual                S             S
# 1                      Anti-White    Individual                S             S
# 2  Anti-Black or African American    Individual                S             S
# 3                      Anti-White    Individual                M             S
# 4                      Anti-White    Individual                S             S
#
# [5 rows x 28 columns]

# %%
# Check shape of dataframe
df.shape
# Out:
# (209442, 28)

# %% [markdown]
# ## 3. Data Consistency Checks

# %% [markdown]
# ### 3.1 Data Types

# %%
# Print of names of columns
df.columns
# Out:
# Index(['INCIDENT_ID', 'DATA_YEAR', 'ORI', 'PUB_AGENCY_NAME', 'PUB_AGENCY_UNIT',
#        'AGENCY_TYPE_NAME', 'STATE_ABBR', 'STATE_NAME', 'DIVISION_NAME',
#        'REGION_NAME', 'POPULATION_GROUP_CODE', 'POPULATION_GROUP_DESC',
#        'INCIDENT_DATE', 'ADULT_VICTIM_COUNT', 'JUVENILE_VICTIM_COUNT',
#        'TOTAL_OFFENDER_COUNT', 'ADULT_OFFENDER_COUNT',
#        'JUVENILE_OFFENDER_COUNT', 'OFFENDER_RACE', 'OFFENDER_ETHNICITY',
#        'VICTIM_COUNT', 'OFFENSE_NAME', 'TOTAL_INDIVIDUAL_VICTIMS',
#        'LOCATION_NAME', 'BIAS_DESC', 'VICTIM_TYPES', 'MULTIPLE_OFFENSE',
#        'MULTIPLE_BIAS'],
#       dtype='object')

# %%
# Print of number of rows and columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209442 entries, 0 to 209441
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   INCIDENT_ID               209442 non-null  int64
#  1   DATA_YEAR                 209442 non-null  int64
#  2   ORI                       209442 non-null  object
#  3   PUB_AGENCY_NAME           209442 non-null  object
#  4   PUB_AGENCY_UNIT           5956 non-null    object
#  5   AGENCY_TYPE_NAME          209442 non-null  object
#  6   STATE_ABBR                209442 non-null  object
#  7   STATE_NAME                209442 non-null  object
#  8   DIVISION_NAME             209442 non-null  object
#  9   REGION_NAME               209442 non-null  object
#  10  POPULATION_GROUP_CODE     209442 non-null  object
#  11  POPULATION_GROUP_DESC     209442 non-null  object
#  12  INCIDENT_DATE             209442 non-null  object
#  13  ADULT_VICTIM_COUNT        42562 non-null   float64
#  14  JUVENILE_VICTIM_COUNT     41629 non-null   float64
#  15  TOTAL_OFFENDER_COUNT      209442 non-null  int64
#  16  ADULT_OFFENDER_COUNT      39720 non-null   float64
#  17  JUVENILE_OFFENDER_COUNT   39713 non-null   float64
#  18  OFFENDER_RACE             209422 non-null  object
#  19  OFFENDER_ETHNICITY        25300 non-null   object
#  20  VICTIM_COUNT              209442 non-null  int64
#  21  OFFENSE_NAME              209442 non-null  object
#  22  TOTAL_INDIVIDUAL_VICTIMS  206832 non-null  float64
#  23  LOCATION_NAME             209442 non-null  object
#  24  BIAS_DESC                 209442 non-null  object
#  25  VICTIM_TYPES              209442 non-null  object
#  26  MULTIPLE_OFFENSE          209442 non-null  object
#  27  MULTIPLE_BIAS             209442 non-null  object
# dtypes: float64(5), int64(4), object(19)
# memory usage: 44.7+ MB

# %%
# Apply advanced python function that checks df for mixed type columns
for col in df.columns.tolist():
  weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df[weird]) > 0:
    print (col)
# Out:
# PUB_AGENCY_UNIT
# OFFENDER_RACE
# OFFENDER_ETHNICITY

# %%
# Change data type of 'PUB_AGENCY_UNIT' column to string
df['PUB_AGENCY_UNIT'] = df['PUB_AGENCY_UNIT'].astype('str')

# %%
# Check data type of 'PUB_AGENCY_UNIT' column
df['PUB_AGENCY_UNIT'].dtype
# Out:
# dtype('O')

# %%
# Change data type of 'OFFENDER_RACE' column to string
df['OFFENDER_RACE'] = df['OFFENDER_RACE'].astype('str')

# %%
# Check data type of 'OFFENDER_RACE' column
df['OFFENDER_RACE'].dtype
# Out:
# dtype('O')

# %%
# Change data type of 'OFFENDER_ETHNICITY' column to string
df['OFFENDER_ETHNICITY'] = df['OFFENDER_ETHNICITY'].astype('str')

# %%
# Check data type of 'OFFENDER_ETHNICITY' column
df['OFFENDER_ETHNICITY'].dtype
# Out:
# dtype('O')

# %%
# Apply advanced python function that checks df for mixed type columns
for col in df.columns.tolist():
  weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df[weird]) > 0:
    print (col)

# %%
# Change data type of 'INCIDENT_ID' column to string as doesn't represent number with statistical importance
df['INCIDENT_ID'] = df['INCIDENT_ID'].astype('str')

# %% [markdown]
# ### 3.2 Missing Data

# %%
# Find missing values in df
df.isnull().sum()
# Out:
# INCIDENT_ID                      0
# DATA_YEAR                        0
# ORI                              0
# PUB_AGENCY_NAME                  0
# PUB_AGENCY_UNIT                  0
# AGENCY_TYPE_NAME                 0
# STATE_ABBR                       0
# STATE_NAME                       0
# DIVISION_NAME                    0
# REGION_NAME                      0
# POPULATION_GROUP_CODE            0
# POPULATION_GROUP_DESC            0
# INCIDENT_DATE                    0
# ADULT_VICTIM_COUNT          166880
# JUVENILE_VICTIM_COUNT       167813
# TOTAL_OFFENDER_COUNT             0
# ADULT_OFFENDER_COUNT        169722
# JUVENILE_OFFENDER_COUNT     169729
# OFFENDER_RACE                    0
# OFFENDER_ETHNICITY               0
# VICTIM_COUNT                     0
# OFFENSE_NAME                     0
# TOTAL_INDIVIDUAL_VICTIMS      2610
# LOCATION_NAME                    0
# BIAS_DESC                        0
# VICTIM_TYPES                     0
# MULTIPLE_OFFENSE                 0
# MULTIPLE_BIAS                    0
# dtype: int64

# %%
# Check for missing values in 'PUB_AGENCY_UNIT' column
df['PUB_AGENCY_UNIT'].value_counts(dropna = False)
# Out:
# nan                                  203486
# Ann Arbor                               143
# New Castle County                       136
# College Park                            119
# Storrs, Avery Point, and Hartford       113
#                                       ...
# Pueblo                                    1
# Upperglade                                1
# Surry County                              1
# Ohio County                               1
# Hastings College of Law                   1
# Name: PUB_AGENCY_UNIT, Length: 610, dtype: int64

# %%
# Check for missing values in 'OFFENDER_ETHNICITY' column
df['OFFENDER_ETHNICITY'].value_counts(dropna = False)
# Out:
# nan                       184142
# Unknown                    18696
# Not Hispanic or Latino      5122
# Hispanic or Latino          1339
# Multiple                     143
# Name: OFFENDER_ETHNICITY, dtype: int64

# %%
# Check for missing values in 'OFFENDER_RACE' column
df['OFFENDER_RACE'].value_counts(dropna = False)
# Out:
# Unknown                                      92640
# White                                        82629
# Black or African American                    27191
# Multiple                                      4238
# Asian                                         1514
# American Indian or Alaska Native              1154
# Native Hawaiian or Other Pacific Islander       56
# nan                                             20
# Name: OFFENDER_RACE, dtype: int64

# %%
# Create new dataframe dropping columns with too many missing values
df_drop = df.drop(columns = ['ADULT_VICTIM_COUNT','JUVENILE_VICTIM_COUNT','ADULT_OFFENDER_COUNT','JUVENILE_OFFENDER_COUNT'])

# %%
# Check shape of dataframe
df_drop.shape
# Out:
# (209442, 24)

# %%
# Check head of dataframe
df_drop.head()
# Out:
#   INCIDENT_ID  DATA_YEAR        ORI PUB_AGENCY_NAME PUB_AGENCY_UNIT  \
# 0        3015       1991  AR0040200          Rogers             nan
# 1        3016       1991  AR0290100            Hope             nan
# 2          43       1991  AR0350100      Pine Bluff             nan
# 3          44       1991  AR0350100      Pine Bluff             nan
# 4        3017       1991  AR0350100      Pine Bluff             nan
#
#   AGENCY_TYPE_NAME STATE_ABBR STATE_NAME       DIVISION_NAME REGION_NAME  ...  \
# 0             City         AR   Arkansas  West South Central       South  ...
# 1             City         AR   Arkansas  West South Central       South  ...
# 2             City         AR   Arkansas  West South Central       South  ...
# 3             City         AR   Arkansas  West South Central       South  ...
# 4             City         AR   Arkansas  West South Central       South  ...
#
#                OFFENDER_RACE OFFENDER_ETHNICITY VICTIM_COUNT  \
# 0                      White                nan            1
# 1  Black or African American                nan            1
# 2  Black or African American                nan            1
# 3  Black or African American                nan            2
# 4  Black or African American                nan            1
#
#                                         OFFENSE_NAME TOTAL_INDIVIDUAL_VICTIMS  \
# 0                                       Intimidation                      1.0
# 1                                     Simple Assault                      1.0
# 2                                 Aggravated Assault                      1.0
# 3  Aggravated Assault;Destruction/Damage/Vandalis...                      1.0
# 4                                 Aggravated Assault                      1.0
#
#                         LOCATION_NAME                       BIAS_DESC  \
# 0  Highway/Road/Alley/Street/Sidewalk  Anti-Black or African American
# 1  Highway/Road/Alley/Street/Sidewalk                      Anti-White
# 2                      Residence/Home  Anti-Black or African American
# 3  Highway/Road/Alley/Street/Sidewalk                      Anti-White
# 4                 Service/Gas Station                      Anti-White
#
#   VICTIM_TYPES  MULTIPLE_OFFENSE MULTIPLE_BIAS
# 0   Individual                 S             S
# 1   Individual                 S             S
# 2   Individual                 S             S
# 3   Individual                 M             S
# 4   Individual                 S             S
#
# [5 rows x 24 columns]

# %%
# Drop additional column with too many missing values
df_drop = df_drop.drop(columns = ['PUB_AGENCY_UNIT'])

# %%
# Check shape of dataframe
df_drop.shape
# Out:
# (209442, 23)

# %%
# Check head of dataframe
df_drop.head()
# Out:
#   INCIDENT_ID  DATA_YEAR        ORI PUB_AGENCY_NAME AGENCY_TYPE_NAME  \
# 0        3015       1991  AR0040200          Rogers             City
# 1        3016       1991  AR0290100            Hope             City
# 2          43       1991  AR0350100      Pine Bluff             City
# 3          44       1991  AR0350100      Pine Bluff             City
# 4        3017       1991  AR0350100      Pine Bluff             City
#
#   STATE_ABBR STATE_NAME       DIVISION_NAME REGION_NAME POPULATION_GROUP_CODE  \
# 0         AR   Arkansas  West South Central       South                     5
# 1         AR   Arkansas  West South Central       South                     6
# 2         AR   Arkansas  West South Central       South                     3
# 3         AR   Arkansas  West South Central       South                     3
# 4         AR   Arkansas  West South Central       South                     3
#
#    ...              OFFENDER_RACE OFFENDER_ETHNICITY  VICTIM_COUNT  \
# 0  ...                      White                nan             1
# 1  ...  Black or African American                nan             1
# 2  ...  Black or African American                nan             1
# 3  ...  Black or African American                nan             2
# 4  ...  Black or African American                nan             1
#
#                                         OFFENSE_NAME TOTAL_INDIVIDUAL_VICTIMS  \
# 0                                       Intimidation                      1.0
# 1                                     Simple Assault                      1.0
# 2                                 Aggravated Assault                      1.0
# 3  Aggravated Assault;Destruction/Damage/Vandalis...                      1.0
# 4                                 Aggravated Assault                      1.0
#
#                         LOCATION_NAME                       BIAS_DESC  \
# 0  Highway/Road/Alley/Street/Sidewalk  Anti-Black or African American
# 1  Highway/Road/Alley/Street/Sidewalk                      Anti-White
# 2                      Residence/Home  Anti-Black or African American
# 3  Highway/Road/Alley/Street/Sidewalk                      Anti-White
# 4                 Service/Gas Station                      Anti-White
#
#    VICTIM_TYPES MULTIPLE_OFFENSE MULTIPLE_BIAS
# 0    Individual                S             S
# 1    Individual                S             S
# 2    Individual                S             S
# 3    Individual                M             S
# 4    Individual                S             S
#
# [5 rows x 23 columns]

# %% [markdown]
# ### 3.3 Duplicate Data

# %%
# Search for duplicated rows in df_drop and create a subset that contains only these rows
df_dups = df_drop[df_drop.duplicated()]

# %%
# Visualise df_dups subset that contains duplicated rows
df_dups
# Out:
# Empty DataFrame
# Columns: [INCIDENT_ID, DATA_YEAR, ORI, PUB_AGENCY_NAME, AGENCY_TYPE_NAME, STATE_ABBR, STATE_NAME, DIVISION_NAME, REGION_NAME, POPULATION_GROUP_CODE, POPULATION_GROUP_DESC, INCIDENT_DATE, TOTAL_OFFENDER_COUNT, OFFENDER_RACE, OFFENDER_ETHNICITY, VICTIM_COUNT, OFFENSE_NAME, TOTAL_INDIVIDUAL_VICTIMS, LOCATION_NAME, BIAS_DESC, VICTIM_TYPES, MULTIPLE_OFFENSE, MULTIPLE_BIAS]
# Index: []
#
# [0 rows x 23 columns]

# %%
# There are no duplicated rows

# %% [markdown]
# ### 3.4 Descriptive Statistics

# %%
# Print of descriptive statistics of df_drop
df_drop.describe()
# Out:
#            DATA_YEAR  TOTAL_OFFENDER_COUNT   VICTIM_COUNT  \
# count  209442.000000         209442.000000  209442.000000
# mean     2004.768671              0.964563       1.243242
# std         8.163895              1.371743       1.142100
# min      1991.000000              0.000000       1.000000
# 25%      1998.000000              0.000000       1.000000
# 50%      2004.000000              1.000000       1.000000
# 75%      2012.000000              1.000000       1.000000
# max      2019.000000             99.000000     200.000000
#
#        TOTAL_INDIVIDUAL_VICTIMS
# count             206832.000000
# mean                   0.977566
# std                    1.101683
# min                    0.000000
# 25%                    1.000000
# 50%                    1.000000
# 75%                    1.000000
# max                  147.000000

# %%
# Find row(s) where 'TOTAL_OFFENDER_COUNT' number is 99.
df_drop.loc[df_drop['TOTAL_OFFENDER_COUNT']==99]
# Out:
#       INCIDENT_ID  DATA_YEAR        ORI PUB_AGENCY_NAME AGENCY_TYPE_NAME  \
# 17960       15307       1993  TX1750100       Corsicana             City
# 43606       47783       1997  CA0480300       Fairfield             City
#
#       STATE_ABBR  STATE_NAME       DIVISION_NAME REGION_NAME  \
# 17960         TX       Texas  West South Central       South
# 43606         CA  California             Pacific        West
#
#       POPULATION_GROUP_CODE  ...              OFFENDER_RACE  \
# 17960                     5  ...  Black or African American
# 43606                     3  ...                    Unknown
#
#       OFFENDER_ETHNICITY  VICTIM_COUNT  \
# 17960                nan             1
# 43606                nan            50
#
#                                    OFFENSE_NAME TOTAL_INDIVIDUAL_VICTIMS  \
# 17960  Destruction/Damage/Vandalism of Property                      0.0
# 43606                              Intimidation                     50.0
#
#                             LOCATION_NAME                       BIAS_DESC  \
# 17960  Highway/Road/Alley/Street/Sidewalk                      Anti-White
# 43606                      School/College  Anti-Black or African American
#
#        VICTIM_TYPES MULTIPLE_OFFENSE MULTIPLE_BIAS
# 17960         Other                S             S
# 43606    Individual                S             S
#
# [2 rows x 23 columns]

# %%
# Explore values within 'TOTAL_OFFENDER_COUNT' column that are greater than 10 using loc() function
df_drop.loc[df_drop['TOTAL_OFFENDER_COUNT']>10]
# Out:
#        INCIDENT_ID  DATA_YEAR        ORI PUB_AGENCY_NAME AGENCY_TYPE_NAME  \
# 241           2900       1991  CT0015600      West Haven             City
# 399            397       1991  IA0850100            Ames             City
# 426            173       1991  ID0100200     Idaho Falls             City
# 431            273       1991  ID0100200     Idaho Falls             City
# 476            243       1991  ILCPD0000         Chicago             City
# ...            ...        ...        ...             ...              ...
# 194930      390561       2018  CA0194200     Los Angeles             City
# 196871      407178       2018  MA0090200       Arlington             City
# 201967      647055       2019  CA0194200     Los Angeles             City
# 202359      549296       2019  CA0349600  Citrus Heights             City
# 203662      539976       2019  ILCPD0000         Chicago             City
#
#        STATE_ABBR     STATE_NAME       DIVISION_NAME REGION_NAME  \
# 241            CT    Connecticut         New England   Northeast
# 399            IA           Iowa  West North Central     Midwest
# 426            ID          Idaho            Mountain        West
# 431            ID          Idaho            Mountain        West
# 476            IL       Illinois  East North Central     Midwest
# ...           ...            ...                 ...         ...
# 194930         CA     California             Pacific        West
# 196871         MA  Massachusetts         New England   Northeast
# 201967         CA     California             Pacific        West
# 202359         CA     California             Pacific        West
# 203662         IL       Illinois  East North Central     Midwest
#
#        POPULATION_GROUP_CODE  ...              OFFENDER_RACE  \
# 241                        3  ...                      White
# 399                        4  ...                      White
# 426                        4  ...                      White
# 431                        4  ...                      White
# 476                       1A  ...                      White
# ...                      ...  ...                        ...
# 194930                    1A  ...                      White
# 196871                     4  ...                    Unknown
# 201967                    1A  ...  Black or African American
# 202359                     3  ...                    Unknown
# 203662                    1A  ...  Black or African American
#
#         OFFENDER_ETHNICITY  VICTIM_COUNT  \
# 241                    nan             1
# 399                    nan             1
# 426                    nan            25
# 431                    nan            26
# 476                    nan             6
# ...                    ...           ...
# 194930  Hispanic or Latino             1
# 196871             Unknown             1
# 201967             Unknown             1
# 202359             Unknown             1
# 203662             Unknown             6
#
#                                     OFFENSE_NAME TOTAL_INDIVIDUAL_VICTIMS  \
# 241                                 Intimidation                      1.0
# 399                               Simple Assault                      1.0
# 426                               Simple Assault                     25.0
# 431                               Simple Assault                     26.0
# 476                           Aggravated Assault                      6.0
# ...                                          ...                      ...
# 194930                            Simple Assault                      1.0
# 196871  Destruction/Damage/Vandalism of Property                      0.0
# 201967                        Aggravated Assault                      1.0
# 202359  Destruction/Damage/Vandalism of Property                      1.0
# 203662   Aggravated Assault;Intimidation;Robbery                      6.0
#
#                              LOCATION_NAME  \
# 241     Highway/Road/Alley/Street/Sidewalk
# 399             Government/Public Building
# 426     Highway/Road/Alley/Street/Sidewalk
# 431     Highway/Road/Alley/Street/Sidewalk
# 476     Highway/Road/Alley/Street/Sidewalk
# ...                                    ...
# 194930             Parking/Drop Lot/Garage
# 196871         School-Elementary/Secondary
# 201967                      Residence/Home
# 202359                      Residence/Home
# 203662              Air/Bus/Train Terminal
#
#                                                 BIAS_DESC  VICTIM_TYPES  \
# 241                        Anti-Black or African American    Individual
# 399     Anti-Lesbian, Gay, Bisexual, or Transgender (M...    Individual
# 426                                            Anti-White    Individual
# 431                               Anti-Hispanic or Latino    Individual
# 476                        Anti-Black or African American    Individual
# ...                                                   ...           ...
# 194930                                    Anti-Gay (Male)    Individual
# 196871              Anti-Gay (Male);Anti-Lesbian (Female)    Government
# 201967                            Anti-Hispanic or Latino    Individual
# 202359                                    Anti-Gay (Male)    Individual
# 203662                                    Anti-Gay (Male)    Individual
#
#        MULTIPLE_OFFENSE MULTIPLE_BIAS
# 241                   S             S
# 399                   S             S
# 426                   S             S
# 431                   S             S
# 476                   S             S
# ...                 ...           ...
# 194930                S             S
# 196871                S             M
# 201967                S             S
# 202359                S             S
# 203662                M             S
#
# [379 rows x 23 columns]

# %%
# Explore values within 'TOTAL_OFFENDER_COUNT' column that are greater than 20 using loc() function
df_drop.loc[df_drop['TOTAL_OFFENDER_COUNT']>20]
# Out:
#        INCIDENT_ID  DATA_YEAR        ORI  \
# 426            173       1991  ID0100200
# 431            273       1991  ID0100200
# 476            243       1991  ILCPD0000
# 487            254       1991  ILCPD0000
# 1136           616       1991  MD0172100
# 3602          4210       1991  OK0720500
# 5613          5208       1992  GAAPD0000
# 5854          5315       1992  ILCPD0000
# 5860          5321       1992  ILCPD0000
# 5947          9806       1992  ILCPD0000
# 6038          5490       1992  IN0710200
# 6937          5425       1992  MDBPD0000
# 7260          9586       1992  MOSPD0000
# 10224         7981       1992  TX0210100
# 10629         7949       1992  TXDPD0000
# 11968        15853       1993  CO0210100
# 12655        12214       1993  IL0100100
# 13208        12151       1993  ILCPD0000
# 13223        12166       1993  ILCPD0000
# 13224        12167       1993  ILCPD0000
# 13311        16917       1993  ILCPD0000
# 14467        13168       1993  MI7047400
# 17073        16602       1993  OK0720500
# 17960        15307       1993  TX1750100
# 17971        18432       1993  TX1750100
# 18718        15475       1993  WASPD0000
# 18776        15533       1993  WASPD0000
# 20190        19677       1994  ILCPD0000
# 20709        20081       1994  MD0230300
# 23845        22001       1994  RI0030400
# 24063        22252       1994  TX1750100
# 29234        27301       1995  MOKPD0000
# 36260        38465       1996  KY1200100
# 40155        36842       1996  OHCLP0000
# 43606        47783       1997  CA0480300
# 46322        44283       1997  MO0110000
# 46323        46852       1997  MO0110000
# 52526        51103       1998  ILCPD0000
# 56022        53251       1998  OH0090500
# 56091        53298       1998  OH0490100
# 56615        53588       1998  RI004239E
# 74221        83091       2001  CA0070100
# 74663        74277       2001  CA0194200
# 74664        74278       2001  CA0194200
# 74866        80848       2001  CA0194200
# 74867        80849       2001  CA0194200
# 98726       103178       2004  AZ0072300
# 114386      113998       2006  CA0195300
# 119746      121117       2006  OR0090100
# 129635      129396       2008  CA0194200
# 137118      137033       2009  AZ0072300
# 137727      141237       2009  CA0195500
# 144289      147984       2010  CA0194200
# 169789      169775       2014  CA0194200
# 175021      174998       2015  AZ0072300
# 194930      390561       2018  CA0194200
#
#                                  PUB_AGENCY_NAME       AGENCY_TYPE_NAME  \
# 426                                  Idaho Falls                   City
# 431                                  Idaho Falls                   City
# 476                                      Chicago                   City
# 487                                      Chicago                   City
# 1136    Prince George's County Police Department                 County
# 3602                                       Tulsa                   City
# 5613                                     Atlanta                   City
# 5854                                     Chicago                   City
# 5860                                     Chicago                   City
# 5947                                     Chicago                   City
# 6038                                  South Bend                   City
# 6937                                   Baltimore                   City
# 7260                                   St. Louis                   City
# 10224                                      Bryan                   City
# 10629                                     Dallas                   City
# 11968                           Colorado Springs                   City
# 12655                                  Champaign                   City
# 13208                                    Chicago                   City
# 13223                                    Chicago                   City
# 13224                                    Chicago                   City
# 13311                                    Chicago                   City
# 14467                                    Holland                   City
# 17073                                      Tulsa                   City
# 17960                                  Corsicana                   City
# 17971                                  Corsicana                   City
# 18718                                    Seattle                   City
# 18776                                    Seattle                   City
# 20190                                    Chicago                   City
# 20709                                  Salisbury                   City
# 23845                                 Portsmouth                   City
# 24063                                  Corsicana                   City
# 29234                                Kansas City                   City
# 36260                                 Versailles                   City
# 40155                                  Cleveland                   City
# 43606                                  Fairfield                   City
# 46322                                   Buchanan                 County
# 46323                                   Buchanan                 County
# 52526                                    Chicago                   City
# 56022                                     Monroe                   City
# 56091                                     London                   City
# 56615                           Brown University  University or College
# 74221                                    Antioch                   City
# 74663                                Los Angeles                   City
# 74664                                Los Angeles                   City
# 74866                                Los Angeles                   City
# 74867                                Los Angeles                   City
# 98726                                    Phoenix                   City
# 114386                                  Pasadena                   City
# 119746                                      Bend                   City
# 129635                               Los Angeles                   City
# 137118                                   Phoenix                   City
# 137727                                    Pomona                   City
# 144289                               Los Angeles                   City
# 169789                               Los Angeles                   City
# 175021                                   Phoenix                   City
# 194930                               Los Angeles                   City
#
#        STATE_ABBR    STATE_NAME       DIVISION_NAME REGION_NAME  \
# 426            ID         Idaho            Mountain        West
# 431            ID         Idaho            Mountain        West
# 476            IL      Illinois  East North Central     Midwest
# 487            IL      Illinois  East North Central     Midwest
# 1136           MD      Maryland      South Atlantic       South
# 3602           OK      Oklahoma  West South Central       South
# 5613           GA       Georgia      South Atlantic       South
# 5854           IL      Illinois  East North Central     Midwest
# 5860           IL      Illinois  East North Central     Midwest
# 5947           IL      Illinois  East North Central     Midwest
# 6038           IN       Indiana  East North Central     Midwest
# 6937           MD      Maryland      South Atlantic       South
# 7260           MO      Missouri  West North Central     Midwest
# 10224          TX         Texas  West South Central       South
# 10629          TX         Texas  West South Central       South
# 11968          CO      Colorado            Mountain        West
# 12655          IL      Illinois  East North Central     Midwest
# 13208          IL      Illinois  East North Central     Midwest
# 13223          IL      Illinois  East North Central     Midwest
# 13224          IL      Illinois  East North Central     Midwest
# 13311          IL      Illinois  East North Central     Midwest
# 14467          MI      Michigan  East North Central     Midwest
# 17073          OK      Oklahoma  West South Central       South
# 17960          TX         Texas  West South Central       South
# 17971          TX         Texas  West South Central       South
# 18718          WA    Washington             Pacific        West
# 18776          WA    Washington             Pacific        West
# 20190          IL      Illinois  East North Central     Midwest
# 20709          MD      Maryland      South Atlantic       South
# 23845          RI  Rhode Island         New England   Northeast
# 24063          TX         Texas  West South Central       South
# 29234          MO      Missouri  West North Central     Midwest
# 36260          KY      Kentucky  East South Central       South
# 40155          OH          Ohio  East North Central     Midwest
# 43606          CA    California             Pacific        West
# 46322          MO      Missouri  West North Central     Midwest
# 46323          MO      Missouri  West North Central     Midwest
# 52526          IL      Illinois  East North Central     Midwest
# 56022          OH          Ohio  East North Central     Midwest
# 56091          OH          Ohio  East North Central     Midwest
# 56615          RI  Rhode Island         New England   Northeast
# 74221          CA    California             Pacific        West
# 74663          CA    California             Pacific        West
# 74664          CA    California             Pacific        West
# 74866          CA    California             Pacific        West
# 74867          CA    California             Pacific        West
# 98726          AZ       Arizona            Mountain        West
# 114386         CA    California             Pacific        West
# 119746         OR        Oregon             Pacific        West
# 129635         CA    California             Pacific        West
# 137118         AZ       Arizona            Mountain        West
# 137727         CA    California             Pacific        West
# 144289         CA    California             Pacific        West
# 169789         CA    California             Pacific        West
# 175021         AZ       Arizona            Mountain        West
# 194930         CA    California             Pacific        West
#
#        POPULATION_GROUP_CODE  ...              OFFENDER_RACE  \
# 426                        4  ...                      White
# 431                        4  ...                      White
# 476                       1A  ...                      White
# 487                       1A  ...                      White
# 1136                      9A  ...  Black or African American
# 3602                      1C  ...  Black or African American
# 5613                      1C  ...  Black or African American
# 5854                      1A  ...  Black or African American
# 5860                      1A  ...  Black or African American
# 5947                      1A  ...  Black or African American
# 6038                       2  ...  Black or African American
# 6937                      1B  ...  Black or African American
# 7260                      1C  ...  Black or African American
# 10224                      3  ...  Black or African American
# 10629                     1A  ...  Black or African American
# 11968                     1C  ...                    Unknown
# 12655                      3  ...                      Asian
# 13208                     1A  ...                   Multiple
# 13223                     1A  ...                      White
# 13224                     1A  ...                   Multiple
# 13311                     1A  ...  Black or African American
# 14467                      4  ...                   Multiple
# 17073                     1C  ...  Black or African American
# 17960                      5  ...  Black or African American
# 17971                      5  ...  Black or African American
# 18718                     1B  ...  Black or African American
# 18776                     1B  ...  Black or African American
# 20190                     1A  ...  Black or African American
# 20709                      5  ...  Black or African American
# 23845                      5  ...                      White
# 24063                      5  ...  Black or African American
# 29234                     1C  ...  Black or African American
# 36260                      6  ...                   Multiple
# 40155                     1C  ...                   Multiple
# 43606                      3  ...                    Unknown
# 46322                     9C  ...                      White
# 46323                     9C  ...  Black or African American
# 52526                     1A  ...                      White
# 56022                      6  ...                      White
# 56091                      6  ...                    Unknown
# 56615                      7  ...                      White
# 74221                      3  ...  Black or African American
# 74663                     1A  ...  Black or African American
# 74664                     1A  ...  Black or African American
# 74866                     1A  ...  Black or African American
# 74867                     1A  ...  Black or African American
# 98726                     1A  ...                      White
# 114386                     2  ...  Black or African American
# 119746                     3  ...                      White
# 129635                    1A  ...                      White
# 137118                    1A  ...                      White
# 137727                     2  ...                      White
# 144289                    1A  ...                      White
# 169789                    1A  ...                      White
# 175021                    1A  ...                    Unknown
# 194930                    1A  ...                      White
#
#         OFFENDER_ETHNICITY  VICTIM_COUNT  \
# 426                    nan            25
# 431                    nan            26
# 476                    nan             6
# 487                    nan             1
# 1136                   nan            10
# 3602                   nan             2
# 5613                   nan             1
# 5854                   nan             5
# 5860                   nan             1
# 5947                   nan             1
# 6038                   nan             2
# 6937                   nan             1
# 7260                   nan             1
# 10224                  nan             3
# 10629                  nan            22
# 11968                  nan             1
# 12655                  nan             2
# 13208                  nan             1
# 13223                  nan             5
# 13224                  nan             3
# 13311                  nan             3
# 14467                  nan             1
# 17073                  nan             3
# 17960                  nan             1
# 17971                  nan             1
# 18718                  nan             2
# 18776                  nan             1
# 20190                  nan             2
# 20709                  nan             2
# 23845                  nan             1
# 24063                  nan             7
# 29234                  nan             1
# 36260                  nan             6
# 40155                  nan             9
# 43606                  nan            50
# 46322                  nan             3
# 46323                  nan             6
# 52526                  nan             2
# 56022                  nan             1
# 56091                  nan             2
# 56615                  nan             2
# 74221                  nan             3
# 74663                  nan             1
# 74664                  nan             1
# 74866                  nan             3
# 74867                  nan             3
# 98726                  nan             2
# 114386                 nan             3
# 119746                 nan             1
# 129635                 nan             4
# 137118                 nan             7
# 137727                 nan             1
# 144289                 nan             1
# 169789                 nan             3
# 175021                 nan             1
# 194930  Hispanic or Latino             1
#
#                                              OFFENSE_NAME  \
# 426                                        Simple Assault
# 431                                        Simple Assault
# 476                                    Aggravated Assault
# 487                                    Aggravated Assault
# 1136                                       Simple Assault
# 3602                                   Aggravated Assault
# 5613             Destruction/Damage/Vandalism of Property
# 5854                                   Aggravated Assault
# 5860             Destruction/Damage/Vandalism of Property
# 5947             Destruction/Damage/Vandalism of Property
# 6038                                       Simple Assault
# 6937                                   Aggravated Assault
# 7260                                         Intimidation
# 10224                                      Simple Assault
# 10629   Destruction/Damage/Vandalism of Property;Intim...
# 11968            Destruction/Damage/Vandalism of Property
# 12655                                      Simple Assault
# 13208                                  Aggravated Assault
# 13223                                  Aggravated Assault
# 13224                                  Aggravated Assault
# 13311                                  Aggravated Assault
# 14467                                      Simple Assault
# 17073                                        Intimidation
# 17960            Destruction/Damage/Vandalism of Property
# 17971            Destruction/Damage/Vandalism of Property
# 18718                                  Aggravated Assault
# 18776                                  Aggravated Assault
# 20190                                      Simple Assault
# 20709                                  Aggravated Assault
# 23845            Destruction/Damage/Vandalism of Property
# 24063                                  Aggravated Assault
# 29234                                        Intimidation
# 36260   Aggravated Assault;Destruction/Damage/Vandalis...
# 40155   Destruction/Damage/Vandalism of Property;Intim...
# 43606                                        Intimidation
# 46322                                        Intimidation
# 46323                                  Aggravated Assault
# 52526                                      Simple Assault
# 56022                                        Intimidation
# 56091                                        Intimidation
# 56615                                        Intimidation
# 74221                                  Aggravated Assault
# 74663                                      Simple Assault
# 74664                                             Robbery
# 74866                                        Intimidation
# 74867                                      Simple Assault
# 98726                                  Aggravated Assault
# 114386                                 Aggravated Assault
# 119746                                       Intimidation
# 129635                         Aggravated Assault;Robbery
# 137118                        Intimidation;Simple Assault
# 137727               Murder and Nonnegligent Manslaughter
# 144289                                      Not Specified
# 169789                                 Aggravated Assault
# 175021           Destruction/Damage/Vandalism of Property
# 194930                                     Simple Assault
#
#        TOTAL_INDIVIDUAL_VICTIMS                          LOCATION_NAME  \
# 426                        25.0     Highway/Road/Alley/Street/Sidewalk
# 431                        26.0     Highway/Road/Alley/Street/Sidewalk
# 476                         6.0     Highway/Road/Alley/Street/Sidewalk
# 487                         1.0     Highway/Road/Alley/Street/Sidewalk
# 1136                       10.0                         School/College
# 3602                        2.0                 Air/Bus/Train Terminal
# 5613                        1.0     Highway/Road/Alley/Street/Sidewalk
# 5854                        5.0     Highway/Road/Alley/Street/Sidewalk
# 5860                        1.0     Highway/Road/Alley/Street/Sidewalk
# 5947                        1.0                        Specialty Store
# 6038                        2.0     Highway/Road/Alley/Street/Sidewalk
# 6937                        1.0                         Residence/Home
# 7260                        1.0     Highway/Road/Alley/Street/Sidewalk
# 10224                       3.0                          Other/Unknown
# 10629                      14.0     Highway/Road/Alley/Street/Sidewalk
# 11968                       1.0             Commercial/Office Building
# 12655                       2.0                Parking/Drop Lot/Garage
# 13208                       1.0     Highway/Road/Alley/Street/Sidewalk
# 13223                       5.0     Highway/Road/Alley/Street/Sidewalk
# 13224                       3.0                            Field/Woods
# 13311                       3.0     Highway/Road/Alley/Street/Sidewalk
# 14467                       1.0     Highway/Road/Alley/Street/Sidewalk
# 17073                       3.0                         Residence/Home
# 17960                       0.0     Highway/Road/Alley/Street/Sidewalk
# 17971                       0.0     Highway/Road/Alley/Street/Sidewalk
# 18718                       2.0                          Other/Unknown
# 18776                       1.0                 Air/Bus/Train Terminal
# 20190                       2.0     Highway/Road/Alley/Street/Sidewalk
# 20709                       2.0                         Residence/Home
# 23845                       1.0                         Residence/Home
# 24063                       7.0                Parking/Drop Lot/Garage
# 29234                       1.0                         Residence/Home
# 36260                       6.0     Highway/Road/Alley/Street/Sidewalk
# 40155                       9.0                Parking/Drop Lot/Garage
# 43606                      50.0                         School/College
# 46322                       3.0                         Residence/Home
# 46323                       6.0                Parking/Drop Lot/Garage
# 52526                       2.0                Parking/Drop Lot/Garage
# 56022                       1.0                             Restaurant
# 56091                       2.0                         Residence/Home
# 56615                       2.0     Highway/Road/Alley/Street/Sidewalk
# 74221                       3.0                         School/College
# 74663                       1.0                Parking/Drop Lot/Garage
# 74664                       1.0     Highway/Road/Alley/Street/Sidewalk
# 74866                       3.0                         Residence/Home
# 74867                       3.0                         Residence/Home
# 98726                       2.0                         Residence/Home
# 114386                      3.0     Highway/Road/Alley/Street/Sidewalk
# 119746                      1.0     Highway/Road/Alley/Street/Sidewalk
# 129635                      4.0     Highway/Road/Alley/Street/Sidewalk
# 137118                      7.0  Bar/Nightclub;Parking/Drop Lot/Garage
# 137727                      1.0                         Residence/Home
# 144289                      1.0                         Residence/Home
# 169789                      3.0     Highway/Road/Alley/Street/Sidewalk
# 175021                      1.0                         Residence/Home
# 194930                      1.0                Parking/Drop Lot/Garage
#
#                              BIAS_DESC               VICTIM_TYPES  \
# 426                         Anti-White                 Individual
# 431            Anti-Hispanic or Latino                 Individual
# 476     Anti-Black or African American                 Individual
# 487                          Anti-Arab                 Individual
# 1136                        Anti-White                 Individual
# 3602                        Anti-White                 Individual
# 5613                        Anti-White                 Individual
# 5854                        Anti-White                 Individual
# 5860                        Anti-White                 Individual
# 5947                        Anti-Asian                 Individual
# 6038                        Anti-White                 Individual
# 6937                        Anti-White                 Individual
# 7260                        Anti-White                 Individual
# 10224                       Anti-White                 Individual
# 10629                       Anti-White  Individual;Society/Public
# 11968   Anti-Multiple Religions, Group                 Individual
# 12655                       Anti-White                 Individual
# 13208                       Anti-White                 Individual
# 13223   Anti-Black or African American                 Individual
# 13224   Anti-Black or African American                 Individual
# 13311                       Anti-White                 Individual
# 14467                       Anti-White                 Individual
# 17073                       Anti-White                 Individual
# 17960                       Anti-White                      Other
# 17971                       Anti-White                      Other
# 18718                       Anti-White                 Individual
# 18776                  Anti-Gay (Male)                 Individual
# 20190                       Anti-White                 Individual
# 20709                       Anti-White                 Individual
# 23845                       Anti-Asian                 Individual
# 24063                       Anti-White                 Individual
# 29234                       Anti-White                 Individual
# 36260                       Anti-White                 Individual
# 40155   Anti-Black or African American                 Individual
# 43606   Anti-Black or African American                 Individual
# 46322   Anti-Black or African American                 Individual
# 46323                       Anti-White                 Individual
# 52526   Anti-Black or African American                 Individual
# 56022   Anti-Black or African American                 Individual
# 56091   Anti-Black or African American                 Individual
# 56615   Anti-Black or African American                 Individual
# 74221       Anti-Multiple Races, Group                 Individual
# 74663          Anti-Hispanic or Latino                 Individual
# 74664          Anti-Hispanic or Latino                 Individual
# 74866          Anti-Hispanic or Latino                 Individual
# 74867          Anti-Hispanic or Latino                 Individual
# 98726   Anti-Black or African American                 Individual
# 114386         Anti-Hispanic or Latino                 Individual
# 119746  Anti-Black or African American                 Individual
# 129635  Anti-Black or African American                 Individual
# 137118         Anti-Hispanic or Latino                 Individual
# 137727  Anti-Black or African American                 Individual
# 144289  Anti-Black or African American                 Individual
# 169789                Anti-Transgender                 Individual
# 175021  Anti-Black or African American                 Individual
# 194930                 Anti-Gay (Male)                 Individual
#
#        MULTIPLE_OFFENSE MULTIPLE_BIAS
# 426                   S             S
# 431                   S             S
# 476                   S             S
# 487                   S             S
# 1136                  S             S
# 3602                  S             S
# 5613                  S             S
# 5854                  S             S
# 5860                  S             S
# 5947                  S             S
# 6038                  S             S
# 6937                  S             S
# 7260                  S             S
# 10224                 S             S
# 10629                 M             S
# 11968                 S             S
# 12655                 S             S
# 13208                 S             S
# 13223                 S             S
# 13224                 S             S
# 13311                 S             S
# 14467                 S             S
# 17073                 S             S
# 17960                 S             S
# 17971                 S             S
# 18718                 S             S
# 18776                 S             S
# 20190                 S             S
# 20709                 S             S
# 23845                 S             S
# 24063                 S             S
# 29234                 S             S
# 36260                 M             S
# 40155                 M             S
# 43606                 S             S
# 46322                 S             S
# 46323                 S             S
# 52526                 S             S
# 56022                 S             S
# 56091                 S             S
# 56615                 S             S
# 74221                 S             S
# 74663                 S             S
# 74664                 S             S
# 74866                 S             S
# 74867                 S             S
# 98726                 S             S
# 114386                S             S
# 119746                S             S
# 129635                M             S
# 137118                M             S
# 137727                S             S
# 144289                S             S
# 169789                S             S
# 175021                S             S
# 194930                S             S
#
# [56 rows x 23 columns]

# %%
# Find row(s) where 'VICTIM_COUNT' number is 200.
df_drop.loc[df_drop['VICTIM_COUNT']==200]
# Out:
#        INCIDENT_ID  DATA_YEAR        ORI                    PUB_AGENCY_NAME  \
# 188874      190211       2017  GA0670200  Gwinnett County Police Department
#
#        AGENCY_TYPE_NAME STATE_ABBR STATE_NAME   DIVISION_NAME REGION_NAME  \
# 188874           County         GA    Georgia  South Atlantic       South
#
#        POPULATION_GROUP_CODE  ... OFFENDER_RACE OFFENDER_ETHNICITY  \
# 188874                    9A  ...       Unknown                nan
#
#         VICTIM_COUNT                 OFFENSE_NAME TOTAL_INDIVIDUAL_VICTIMS  \
# 188874           200  Intimidation;Simple Assault                    100.0
#
#                          LOCATION_NAME  \
# 188874  Church/Synagogue/Temple/Mosque
#
#                                                BIAS_DESC  VICTIM_TYPES  \
# 188874  Anti-Islamic (Muslim);Anti-Multiple Races, Group    Individual
#
#        MULTIPLE_OFFENSE MULTIPLE_BIAS
# 188874                M             M
#
# [1 rows x 23 columns]

# %%
# Explore values within 'VICTIM_COUNT' column that are greater than 100 using loc() function
df_drop.loc[df_drop['VICTIM_COUNT']>100]
# Out:
#        INCIDENT_ID  DATA_YEAR        ORI                    PUB_AGENCY_NAME  \
# 54279        52221       1998  MT0510000                              Toole
# 188874      190211       2017  GA0670200  Gwinnett County Police Department
#
#        AGENCY_TYPE_NAME STATE_ABBR STATE_NAME   DIVISION_NAME REGION_NAME  \
# 54279            County         MT    Montana        Mountain        West
# 188874           County         GA    Georgia  South Atlantic       South
#
#        POPULATION_GROUP_CODE  ... OFFENDER_RACE OFFENDER_ETHNICITY  \
# 54279                     8D  ...       Unknown                nan
# 188874                    9A  ...       Unknown                nan
#
#         VICTIM_COUNT                 OFFENSE_NAME TOTAL_INDIVIDUAL_VICTIMS  \
# 54279            147                        Arson                    147.0
# 188874           200  Intimidation;Simple Assault                    100.0
#
#                          LOCATION_NAME  \
# 54279                   Residence/Home
# 188874  Church/Synagogue/Temple/Mosque
#
#                                                BIAS_DESC  VICTIM_TYPES  \
# 54279                                Anti-Other Religion    Individual
# 188874  Anti-Islamic (Muslim);Anti-Multiple Races, Group    Individual
#
#        MULTIPLE_OFFENSE MULTIPLE_BIAS
# 54279                 S             S
# 188874                M             M
#
# [2 rows x 23 columns]

# %%
# Explore values within 'VICTIM_COUNT' column that are greater than 50 using loc() function
df_drop.loc[df_drop['VICTIM_COUNT']>50]
# Out:
#        INCIDENT_ID  DATA_YEAR        ORI                    PUB_AGENCY_NAME  \
# 4879          8624       1992  CA0380100                      San Francisco
# 14184        16672       1993  MD0230000                           Wicomico
# 19305        22703       1994  CA0380100                      San Francisco
# 25880        25359       1995  CA0270000                           Monterey
# 34117        33483       1996  CA0309700          University of California:
# 54279        52221       1998  MT0510000                              Toole
# 123890      122771       2007  KY0340300             University of Kentucky
# 182467      182432       2016  IN0451000                            Munster
# 188874      190211       2017  GA0670200  Gwinnett County Police Department
# 196406      348625       2018  INIPD0000                       Indianapolis
#
#              AGENCY_TYPE_NAME STATE_ABBR  STATE_NAME       DIVISION_NAME  \
# 4879                     City         CA  California             Pacific
# 14184                  County         MD    Maryland      South Atlantic
# 19305                    City         CA  California             Pacific
# 25880                  County         CA  California             Pacific
# 34117   University or College         CA  California             Pacific
# 54279                  County         MT     Montana            Mountain
# 123890  University or College         KY    Kentucky  East South Central
# 182467                   City         IN     Indiana  East North Central
# 188874                 County         GA     Georgia      South Atlantic
# 196406                   City         IN     Indiana  East North Central
#
#        REGION_NAME POPULATION_GROUP_CODE  ...              OFFENDER_RACE  \
# 4879          West                    1B  ...                    Unknown
# 14184        South                    8B  ...                      White
# 19305         West                    1B  ...                    Unknown
# 25880         West                    9A  ...                      White
# 34117         West                     7  ...                      White
# 54279         West                    8D  ...                    Unknown
# 123890       South                     7  ...                    Unknown
# 182467     Midwest                     5  ...                    Unknown
# 188874       South                    9A  ...                    Unknown
# 196406     Midwest                    1B  ...  Black or African American
#
#             OFFENDER_ETHNICITY  VICTIM_COUNT  \
# 4879                       nan           100
# 14184                      nan            52
# 19305                      nan           100
# 25880                      nan            90
# 34117                      nan            58
# 54279                      nan           147
# 123890                     nan            80
# 182467                 Unknown            75
# 188874                     nan           200
# 196406  Not Hispanic or Latino            80
#
#                                     OFFENSE_NAME TOTAL_INDIVIDUAL_VICTIMS  \
# 4879    Destruction/Damage/Vandalism of Property                      0.0
# 14184   Destruction/Damage/Vandalism of Property                     52.0
# 19305                               Intimidation                    100.0
# 25880                               Intimidation                     90.0
# 34117                               Intimidation                     58.0
# 54279                                      Arson                    147.0
# 123890                              Intimidation                     80.0
# 182467                              Intimidation                     75.0
# 188874               Intimidation;Simple Assault                    100.0
# 196406                              Intimidation                     80.0
#
#                          LOCATION_NAME  \
# 4879    Church/Synagogue/Temple/Mosque
# 14184          Parking/Drop Lot/Garage
# 19305   Church/Synagogue/Temple/Mosque
# 25880                    Other/Unknown
# 34117                   School/College
# 54279                   Residence/Home
# 123890                  School/College
# 182467       School-College/University
# 188874  Church/Synagogue/Temple/Mosque
# 196406      Commercial/Office Building
#
#                                                BIAS_DESC  VICTIM_TYPES  \
# 4879                                         Anti-Jewish         Other
# 14184                     Anti-Black or African American    Individual
# 19305                                        Anti-Jewish    Individual
# 25880                     Anti-Black or African American    Individual
# 34117                                         Anti-Asian    Individual
# 54279                                Anti-Other Religion    Individual
# 123890                    Anti-Black or African American    Individual
# 182467                                       Anti-Jewish    Individual
# 188874  Anti-Islamic (Muslim);Anti-Multiple Races, Group    Individual
# 196406                                        Anti-White    Individual
#
#        MULTIPLE_OFFENSE MULTIPLE_BIAS
# 4879                  S             S
# 14184                 S             S
# 19305                 S             S
# 25880                 S             S
# 34117                 S             S
# 54279                 S             S
# 123890                S             S
# 182467                S             S
# 188874                M             M
# 196406                S             S
#
# [10 rows x 23 columns]

# %% [markdown]
# ## 4. Export Data

# %%
# Export df_drop and save to 'Prepared Data'
df_drop.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'hate_crime_clean.csv'))
