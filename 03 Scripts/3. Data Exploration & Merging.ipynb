# %% [markdown]
# # Data Exploration

# %% [markdown]
# ## This script contains the following points:

# %% [markdown]
# ### 1. Import Libraries

# %% [markdown]
# ### 2. Import Data

# %% [markdown]
# ### 3. Data Consistency Checks

# %% [markdown]
# ### 4. Descriptive Statistics

# %% [markdown]
# ### 5. Import Additional Data

# %% [markdown]
# ### 6. Merge Data

# %% [markdown]
# ### 7. Concatenating Data

# %% [markdown]
# ### 8. Export Data

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 2. Import Data

# %%
# Creating path string to data folder
path = r'C:\Users\bexlu\Desktop\Career Foundry\Data Immersion\Achievement 6\Project Folder'

# %%
# Importing csv file using os library
df = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'hate_crime_clean_categories.csv'), index_col = False)
# Out:
# C:\Users\bexlu\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (15) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# Print of first five rows of df
df.head()
# Out:
#    Unnamed: 0  INCIDENT_ID  DATA_YEAR        ORI PUB_AGENCY_NAME  \
# 0           0         3015       1991  AR0040200          Rogers
# 1           1         3016       1991  AR0290100            Hope
# 2           2           43       1991  AR0350100      Pine Bluff
# 3           3           44       1991  AR0350100      Pine Bluff
# 4           4         3017       1991  AR0350100      Pine Bluff
#
#   AGENCY_TYPE_NAME STATE_ABBR STATE_NAME       DIVISION_NAME REGION_NAME  ...  \
# 0             City         AR   Arkansas  West South Central       South  ...
# 1             City         AR   Arkansas  West South Central       South  ...
# 2             City         AR   Arkansas  West South Central       South  ...
# 3             City         AR   Arkansas  West South Central       South  ...
# 4             City         AR   Arkansas  West South Central       South  ...
#
#                OFFENDER_RACE OFFENDER_ETHNICITY VICTIM_COUNT  \
# ...

# %%
# Check shape of dataframe
df.shape
# Out:
# (209442, 24)

# %% [markdown]
# ## 3. Data Consistency Checks

# %%
# Print of number of rows and columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209442 entries, 0 to 209441
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Unnamed: 0                 209442 non-null  int64
#  1   INCIDENT_ID                209442 non-null  int64
#  2   DATA_YEAR                  209442 non-null  int64
#  3   ORI                        209442 non-null  object
#  4   PUB_AGENCY_NAME            209442 non-null  object
#  5   AGENCY_TYPE_NAME           209442 non-null  object
#  6   STATE_ABBR                 209442 non-null  object
#  7   STATE_NAME                 209442 non-null  object
#  8   DIVISION_NAME              209442 non-null  object
#  9   REGION_NAME                209442 non-null  object
#  10  POPULATION_GROUP_CODE      209442 non-null  object
#  11  POPULATION_GROUP_DESC      209442 non-null  object
#  12  INCIDENT_DATE              209442 non-null  object
# ...

# %%
# Apply function that checks df for mixed type columns
for col in df.columns.tolist():
  weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df[weird]) > 0:
    print (col)
# Out:
# OFFENDER_RACE
# OFFENDER_ETHNICITY

# %%
# Check frequency of 'OFFENDER_RACE'
df['OFFENDER_RACE'].value_counts(dropna = False)
# Out:
# Unknown                                      92640
# White                                        82629
# Black or African American                    27191
# Multiple                                      4238
# Asian                                         1514
# American Indian or Alaska Native              1154
# Native Hawaiian or Other Pacific Islander       56
# NaN                                             20
# Name: OFFENDER_RACE, dtype: int64

# %%
# Check frequency of 'OFFENDER_ETHNICITY'
df['OFFENDER_ETHNICITY'].value_counts(dropna = False)
# Out:
# NaN                       184142
# Unknown                    18696
# Not Hispanic or Latino      5122
# Hispanic or Latino          1339
# Multiple                     143
# Name: OFFENDER_ETHNICITY, dtype: int64

# %%
# Mixed Data in column 'OFFENDER_RACE' and 'OFFENDER_ETHNICITY' as a result of NaN's

# %% [markdown]
# ## 4. Descriptive Statistics

# %%
# Find count of crimes by state
df.groupby('STATE_NAME').agg({'STATE_NAME':['count']})
# Out:
#                      STATE_NAME
#                           count
# STATE_NAME
# Alabama                     210
# Alaska                      231
# Arizona                    6482
# Arkansas                   1089
# California                34911
# Colorado                   4043
# Connecticut                3567
# Delaware                    914
# District of Columbia       1576
# Federal                      87
# Florida                    5081
# Georgia                    1043
# Guam                          5
# Hawaii                       85
# Idaho                      1202
# Illinois                   5446
# Indiana                    1953
# Iowa                        860
# Kansas                     1728
# Kentucky                   3197
# Louisiana                   542
# Maine                      1238
# Maryland                   5648
# Massachusetts             10801
# Michigan                  11834
# Minnesota                  4511
# Mississippi                 180
# ...

# %%
# Find count of crimes by year
df.groupby('DATA_YEAR').agg({'DATA_YEAR':['count']})
# Out:
#           DATA_YEAR
#               count
# DATA_YEAR
# 1991           4589
# 1992           6667
# 1993           7608
# 1994           5954
# 1995           7950
# 1996           8790
# 1997           8107
# 1998           7902
# 1999           7944
# 2000           8219
# 2001           9730
# 2002           7485
# 2003           7545
# 2004           7685
# 2005           7411
# 2006           7716
# 2007           7625
# 2008           8039
# 2009           6613
# 2010           6631
# 2011           6300
# 2012           6594
# 2013           6044
# 2014           5599
# 2015           5879
# 2016           6273
# 2017           7325
# 2018           7190
# 2019           8028

# %%
# Create dataframe with crimes occuring in 2015
df_2015 = df.loc[df['DATA_YEAR']== 2015]

# %%
# Check new df
df_2015.head()
# Out:
#         Unnamed: 0  INCIDENT_ID  DATA_YEAR        ORI PUB_AGENCY_NAME  \
# 174747      174747       180579       2015  AK0010100       Anchorage
# 174748      174748       180580       2015  AK0010100       Anchorage
# 174749      174749       180581       2015  AK0010100       Anchorage
# 174750      174750       180582       2015  AK0010100       Anchorage
# 174751      174751       180583       2015  AK0010100       Anchorage
#
#        AGENCY_TYPE_NAME STATE_ABBR STATE_NAME DIVISION_NAME REGION_NAME  ...  \
# 174747             City         AK     Alaska       Pacific        West  ...
# 174748             City         AK     Alaska       Pacific        West  ...
# 174749             City         AK     Alaska       Pacific        West  ...
# 174750             City         AK     Alaska       Pacific        West  ...
# 174751             City         AK     Alaska       Pacific        West  ...
#
#                            OFFENDER_RACE OFFENDER_ETHNICITY VICTIM_COUNT  \
# ...

# %%
# Find count of crimes by state for year 2015
df_2015.groupby('STATE_NAME').agg({'STATE_NAME':['count']})
# Out:
#                      STATE_NAME
#                           count
# STATE_NAME
# Alabama                      10
# Alaska                        8
# Arizona                     276
# Arkansas                      6
# California                  837
# Colorado                    107
# Connecticut                  93
# Delaware                     11
# District of Columbia         65
# Florida                      72
# Georgia                      44
# Guam                          1
# Idaho                        34
# Illinois                     90
# Indiana                      63
# Iowa                          6
# Kansas                       62
# Kentucky                    188
# Louisiana                    40
# Maine                        38
# Maryland                     41
# Massachusetts               416
# Michigan                    309
# Minnesota                   109
# Missouri                    100
# Montana                      45
# Nebraska                     19
# ...

# %% [markdown]
# ## 5. Import Additional Data

# %%
# Importing csv file using os library
df_additional = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'additional_data_2015.csv'), index_col = False)

# %%
# Check new df
df_additional.head()
# Out:
#    STATE_NAME  GINI_INDEX  POVERTY_RATE  MEDIAN_HOUSEHOLD_INCOME  \
# 0     Alabama      0.4811         0.154                    44765
# 1      Alaska      0.4322         0.107                    73355
# 2     Arizona      0.4702         0.134                    51492
# 3    Arkansas      0.4773         0.165                    41995
# 4  California      0.4876         0.118                    64500
#
#    EMPLOYMENT_RATE  POPULATION_>16  POPULATION<HIGH_SCHOOL_GRADUATE
# 0             52.6         3878471                           346494
# 1             62.1          571393                            25978
# 2             54.5         5393214                           478515
# 3             54.0         2352507                           194395
# 4             58.1        31068647                          3576743

# %%
# Check shape of new df
df_additional.shape
# Out:
# (52, 7)

# %%
# Print of number of rows and columns
df_additional.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   STATE_NAME                       52 non-null     object
#  1   GINI_INDEX                       52 non-null     float64
#  2   POVERTY_RATE                     52 non-null     float64
#  3   MEDIAN_HOUSEHOLD_INCOME          52 non-null     int64
#  4   EMPLOYMENT_RATE                  52 non-null     float64
#  5   POPULATION_>16                   52 non-null     int64
#  6   POPULATION<HIGH_SCHOOL_GRADUATE  52 non-null     int64
# dtypes: float64(3), int64(3), object(1)
# memory usage: 3.0+ KB

# %%
# Check new df
df_additional.tail()
# Out:
#        STATE_NAME  GINI_INDEX  POVERTY_RATE  MEDIAN_HOUSEHOLD_INCOME  \
# 47     Washington      0.4561         0.097                    64129
# 48  West Virginia      0.4581         0.158                    42019
# 49      Wisconsin      0.4410         0.097                    55638
# 50        Wyoming      0.4374         0.099                    60214
# 51    Puerto Rico      0.5589         0.435                    18626
#
#     EMPLOYMENT_RATE  POPULATION_>16  POPULATION<HIGH_SCHOOL_GRADUATE
# 47             59.2         5741873                           341678
# 48             49.0         1508224                           105215
# 49             64.0         4627790                           221229
# 50             64.1          460730                            22764
# 51             36.2         2833603                           303266

# %%
# Drop 'Puerto Rico' from dataframe
df_additional = df_additional.drop([51])

# %%
# Check end of df_additional
df_additional.tail()
# Out:
#        STATE_NAME  GINI_INDEX  POVERTY_RATE  MEDIAN_HOUSEHOLD_INCOME  \
# 46       Virginia      0.4681         0.099                    66262
# 47     Washington      0.4561         0.097                    64129
# 48  West Virginia      0.4581         0.158                    42019
# 49      Wisconsin      0.4410         0.097                    55638
# 50        Wyoming      0.4374         0.099                    60214
#
#     EMPLOYMENT_RATE  POPULATION_>16  POPULATION<HIGH_SCHOOL_GRADUATE
# 46             60.7         6721590                           411234
# 47             59.2         5741873                           341678
# 48             49.0         1508224                           105215
# 49             64.0         4627790                           221229
# 50             64.1          460730                            22764

# %% [markdown]
# ## 6. Merge Data

# %%
# Merge df_additional on to df_2015 on STATE
df_merge_2015 = df_2015.merge(df_additional, on = ['STATE_NAME'])

# %%
df_merge_2015.head()
# Out:
#    Unnamed: 0  INCIDENT_ID  DATA_YEAR        ORI PUB_AGENCY_NAME  \
# 0      174747       180579       2015  AK0010100       Anchorage
# 1      174748       180580       2015  AK0010100       Anchorage
# 2      174749       180581       2015  AK0010100       Anchorage
# 3      174750       180582       2015  AK0010100       Anchorage
# 4      174751       180583       2015  AK0010100       Anchorage
#
#   AGENCY_TYPE_NAME STATE_ABBR STATE_NAME DIVISION_NAME REGION_NAME  ...  \
# 0             City         AK     Alaska       Pacific        West  ...
# 1             City         AK     Alaska       Pacific        West  ...
# 2             City         AK     Alaska       Pacific        West  ...
# 3             City         AK     Alaska       Pacific        West  ...
# 4             City         AK     Alaska       Pacific        West  ...
#
#                                         Primary_Bias VICTIM_TYPES  \
# 0                                          Anti-Arab   Individual
# ...

# %%
# Create new df for aggregate of crime commited in 2015 by State
df_count_2015 = df_2015.groupby('STATE_NAME').agg({'STATE_NAME':['count']})

# %%
# Check df
df_count_2015
# Out:
#                      STATE_NAME
#                           count
# STATE_NAME
# Alabama                      10
# Alaska                        8
# Arizona                     276
# Arkansas                      6
# California                  837
# Colorado                    107
# Connecticut                  93
# Delaware                     11
# District of Columbia         65
# Florida                      72
# Georgia                      44
# Guam                          1
# Idaho                        34
# Illinois                     90
# Indiana                      63
# Iowa                          6
# Kansas                       62
# Kentucky                    188
# Louisiana                    40
# Maine                        38
# Maryland                     41
# Massachusetts               416
# Michigan                    309
# Minnesota                   109
# Missouri                    100
# Montana                      45
# Nebraska                     19
# ...

# %%
# Merge df_additional on to df_count_2015 on STATE
df_merge_count_2015 = df_count_2015.merge(df_additional, on = ['STATE_NAME'])
# Out:
# C:\Users\bexlu\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:643: UserWarning: merging between different levels can give an unintended result (2 levels on the left,1 on the right)
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-94-bc481231cd79> in <module>
#       1 # Merge df_additional on to df_count_2015 on STATE
# ----> 2 df_merge_count_2015 = df_count_2015.merge(df_additional, on = ['STATE_NAME'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7944         from pandas.core.reshape.merge import merge
#    7945
# -> 7946         return merge(
#    7947             self,
#    7948             right,
#
# ...

# %%
# Add index to df_count_2015
df_count_2015 = df_count_2015.reset_index()

# %%
# Check df
df_count_2015
# Out:
#               STATE_NAME
#                          count
# 0                Alabama    10
# 1                 Alaska     8
# 2                Arizona   276
# 3               Arkansas     6
# 4             California   837
# 5               Colorado   107
# 6            Connecticut    93
# 7               Delaware    11
# 8   District of Columbia    65
# 9                Florida    72
# 10               Georgia    44
# 11                  Guam     1
# 12                 Idaho    34
# 13              Illinois    90
# 14               Indiana    63
# 15                  Iowa     6
# 16                Kansas    62
# 17              Kentucky   188
# 18             Louisiana    40
# 19                 Maine    38
# 20              Maryland    41
# 21         Massachusetts   416
# 22              Michigan   309
# 23             Minnesota   109
# 24              Missouri   100
# 25               Montana    45
# 26              Nebraska    19
# 27                Nevada    58
# ...

# %%
# Merge df_additional on to df_count_2015 on STATE
df_merge_count_2015 = df_count_2015.merge(df_additional, on = ['STATE_NAME'])
# Out:
# C:\Users\bexlu\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:643: UserWarning: merging between different levels can give an unintended result (2 levels on the left,1 on the right)
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-98-bc481231cd79> in <module>
#       1 # Merge df_additional on to df_count_2015 on STATE
# ----> 2 df_merge_count_2015 = df_count_2015.merge(df_additional, on = ['STATE_NAME'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7944         from pandas.core.reshape.merge import merge
#    7945
# -> 7946         return merge(
#    7947             self,
#    7948             right,
#
# ...

# %%
# Rename column 'STATE_NAME' in df_additional
df_additional.rename(columns = {'STATE_NAME':'STATE'},inplace=True)

# %%
# Check head of df
df_additional.head()
# Out:
#         STATE  GINI_INDEX  POVERTY_RATE  MEDIAN_HOUSEHOLD_INCOME  \
# 0     Alabama      0.4811         0.154                    44765
# 1      Alaska      0.4322         0.107                    73355
# 2     Arizona      0.4702         0.134                    51492
# 3    Arkansas      0.4773         0.165                    41995
# 4  California      0.4876         0.118                    64500
#
#    EMPLOYMENT_RATE  POPULATION_>16  POPULATION<HIGH_SCHOOL_GRADUATE
# 0             52.6         3878471                           346494
# 1             62.1          571393                            25978
# 2             54.5         5393214                           478515
# 3             54.0         2352507                           194395
# 4             58.1        31068647                          3576743

# %%
# Merge df_additional on to df_count_2015 on STATE
df_merge_count_2015 = df_count_2015.merge(df_additional, on = ['STATE'])
# Out:
# C:\Users\bexlu\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:643: UserWarning: merging between different levels can give an unintended result (2 levels on the left,1 on the right)
#   warnings.warn(msg, UserWarning)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-104-0cf54f2f37c8> in <module>
#       1 # Merge df_additional on to df_count_2015 on STATE
# ----> 2 df_merge_count_2015 = df_count_2015.merge(df_additional, on = ['STATE'])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7944         from pandas.core.reshape.merge import merge
#    7945
# -> 7946         return merge(
#    7947             self,
#    7948             right,
#
# ...

# %%
df_additional.index.nlevels
# Out:
# 1

# %%
df_count_2015.index.nlevels
# Out:
# 1

# %% [markdown]
# ## 7. Concatenating Data

# %%
# Check shape of df's to concatenate
df_additional.shape
# Out:
# (51, 7)

# %%
df_count_2015.shape
# Out:
# (50, 2)

# %%
# Export df_drop and save to 'Prepared Data' to explore differences between df shapes
df_count_2015.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'df_2015.csv'))

# %%
# df_count_2015 has no data for Hawaii and Mississippi
# df_additional has no data for Guam
# Need to remove above observations in order to concatenate

# %%
# Find index number of observations to be dropped 
df_additional
# Out:
#                    STATE  GINI_INDEX  POVERTY_RATE  MEDIAN_HOUSEHOLD_INCOME  \
# 0                Alabama      0.4811         0.154                    44765
# 1                 Alaska      0.4322         0.107                    73355
# 2                Arizona      0.4702         0.134                    51492
# 3               Arkansas      0.4773         0.165                    41995
# 4             California      0.4876         0.118                    64500
# 5               Colorado      0.4580         0.094                    63909
# 6            Connecticut      0.4916         0.102                    71346
# 7               Delaware      0.4523         0.109                    61255
# 8   District of Columbia      0.5354         0.143                    75628
# 9                Florida      0.4872         0.127                    49426
# 10               Georgia      0.4801         0.134                    51244
# ...

# %%
# Drop 'Hawaii' and 'Mississippi' from dataframe
df_additional = df_additional.drop([11,24])

# %%
# Find index number of observations to be dropped 
df_count_2015
# Out:
#               STATE_NAME
#                          count
# 0                Alabama    10
# 1                 Alaska     8
# 2                Arizona   276
# 3               Arkansas     6
# 4             California   837
# 5               Colorado   107
# 6            Connecticut    93
# 7               Delaware    11
# 8   District of Columbia    65
# 9                Florida    72
# 10               Georgia    44
# 11                  Guam     1
# 12                 Idaho    34
# 13              Illinois    90
# 14               Indiana    63
# 15                  Iowa     6
# 16                Kansas    62
# 17              Kentucky   188
# 18             Louisiana    40
# 19                 Maine    38
# 20              Maryland    41
# 21         Massachusetts   416
# 22              Michigan   309
# 23             Minnesota   109
# 24              Missouri   100
# 25               Montana    45
# 26              Nebraska    19
# 27                Nevada    58
# ...

# %%
# Drop 'Guam' from dataframe
df_count_2015 = df_count_2015.drop([11])

# %%
# Check shape of df's to concatenate
df_additional.shape
# Out:
# (49, 7)

# %%
df_additional
# Out:
#                    STATE  GINI_INDEX  POVERTY_RATE  MEDIAN_HOUSEHOLD_INCOME  \
# 0                Alabama      0.4811         0.154                    44765
# 1                 Alaska      0.4322         0.107                    73355
# 2                Arizona      0.4702         0.134                    51492
# 3               Arkansas      0.4773         0.165                    41995
# 4             California      0.4876         0.118                    64500
# 5               Colorado      0.4580         0.094                    63909
# 6            Connecticut      0.4916         0.102                    71346
# 7               Delaware      0.4523         0.109                    61255
# 8   District of Columbia      0.5354         0.143                    75628
# 9                Florida      0.4872         0.127                    49426
# 10               Georgia      0.4801         0.134                    51244
# ...

# %%
df_count_2015.shape
# Out:
# (49, 2)

# %%
# Create list containing df's to concatenate
frames = [df_count_2015, df_additional]

# %%
# Concatenate df's
df_concat = pd.concat(frames, axis = 1)

# %%
df_concat
# Out:
#           (STATE_NAME, )  (STATE_NAME, count)                 STATE  \
# 0                Alabama                 10.0               Alabama
# 1                 Alaska                  8.0                Alaska
# 2                Arizona                276.0               Arizona
# 3               Arkansas                  6.0              Arkansas
# 4             California                837.0            California
# 5               Colorado                107.0              Colorado
# 6            Connecticut                 93.0           Connecticut
# 7               Delaware                 11.0              Delaware
# 8   District of Columbia                 65.0  District of Columbia
# 9                Florida                 72.0               Florida
# 10               Georgia                 44.0               Georgia
# 12                 Idaho                 34.0                 Idaho
# 13              Illinois                 90.0              Illinois
# ...

# %%
# Reset index of dataframe
df_count_2015.reset_index(drop=True, inplace=True)

# %%
# Reset index of dataframe to remove NaN's when df's concatenated
df_additional.reset_index(drop=True, inplace=True)

# %%
# Concatenate df's
df_concat = pd.concat(frames, axis = 1)

# %%
df_concat
# NaN removed
# Out:
#           (STATE_NAME, )  (STATE_NAME, count)                 STATE  \
# 0                Alabama                   10               Alabama
# 1                 Alaska                    8                Alaska
# 2                Arizona                  276               Arizona
# 3               Arkansas                    6              Arkansas
# 4             California                  837            California
# 5               Colorado                  107              Colorado
# 6            Connecticut                   93           Connecticut
# 7               Delaware                   11              Delaware
# 8   District of Columbia                   65  District of Columbia
# 9                Florida                   72               Florida
# 10               Georgia                   44               Georgia
# 11                 Idaho                   34                 Idaho
# 12              Illinois                   90              Illinois
# ...

# %%
# Check shape of df_concat
df_concat.shape
# Out:
# (49, 9)

# %%
# Check column names
df_concat.columns
# Out:
# Index([               ('STATE_NAME', ''),           ('STATE_NAME', 'count'),
#                                  'STATE',                      'GINI_INDEX',
#                           'POVERTY_RATE',         'MEDIAN_HOUSEHOLD_INCOME',
#                        'EMPLOYMENT_RATE',                  'POPULATION_>16',
#        'POPULATION<HIGH_SCHOOL_GRADUATE'],
#       dtype='object')

# %%
# Rename columns that are unclear
df.rename(columns = {''STATE_NAME', ''' : 'STATE_NAME', '('STATE_NAME', 'count')': 'TOTAL_CRIMES'}, inplace = True)
# Out:
#   File "<ipython-input-139-81630ac8f523>", line 2
#     df.rename(columns = {''STATE_NAME', ''' : 'STATE_NAME', '('STATE_NAME', 'count')': 'TOTAL_CRIMES'}, inplace = True)
#                            ^
# SyntaxError: invalid syntax

# %%
# Will export data and fix column names using Excel

# %% [markdown]
# ## 8. Export Data

# %%
# Export df_concat and save to 'Prepared Data'
df_concat.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'hate_crime_2015.csv'))
